# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
breast_cancer_data=sklearn.datasets.load_breast_cancer()
b_df=pd.DataFrame(breast_cancer_data.data,columns=breast_cancer_data.feature_names)
b_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
b_df['label'] = breast_cancer_data.target
b_df.tail()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  label
# 564                0.2216          0.2060                  0.07115      0
# 565                0.1628          0.2572                  0.06637      0
# 566                0.1418          0.2218                  0.07820      0
# 567                0.2650          0.4087                  0.12400      0
# 568                0.0000          0.2871                  0.07039      1
#
# [5 rows x 31 columns]

# %%
b_df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst texture  \
# count     569.000000              569.000000  ...     569.000000
# mean        0.181162                0.062798  ...      25.677223
# std         0.027414                0.007060  ...       6.146258
# min         0.106000                0.049960  ...      12.020000
# 25%         0.161900                0.057700  ...      21.080000
# 50%         0.179200                0.061540  ...      25.410000
# 75%         0.195700                0.066120  ...      29.720000
# max         0.304000                0.097440  ...      49.540000
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# count       569.000000   569.000000        569.000000         569.000000
# mean        107.261213   880.583128          0.132369           0.254265
# std          33.602542   569.356993          0.022832           0.157336
# min          50.410000   185.200000          0.071170           0.027290
# 25%          84.110000   515.300000          0.116600           0.147200
# 50%          97.660000   686.500000          0.131300           0.211900
# 75%         125.400000  1084.000000          0.146000           0.339100
# max         251.200000  4254.000000          0.222600           1.058000
#
#        worst concavity  worst concave points  worst symmetry  \
# count       569.000000            569.000000      569.000000
# mean          0.272188              0.114606        0.290076
# std           0.208624              0.065732        0.061867
# min           0.000000              0.000000        0.156500
# 25%           0.114500              0.064930        0.250400
# 50%           0.226700              0.099930        0.282200
# 75%           0.382900              0.161400        0.317900
# max           1.252000              0.291000        0.663800
#
#        worst fractal dimension       label
# count               569.000000  569.000000
# mean                  0.083946    0.627417
# std                   0.018061    0.483918
# min                   0.055040    0.000000
# 25%                   0.071460    0.000000
# 50%                   0.080040    1.000000
# 75%                   0.092080    1.000000
# max                   0.207500    1.000000
#
# [8 rows x 31 columns]

# %%
b_df['label'].value_counts()
b_df.groupby('label').mean()
# Out:
#        mean radius  mean texture  mean perimeter   mean area  mean smoothness  \
# label
# 0        17.462830     21.604906      115.365377  978.376415         0.102898
# 1        12.146524     17.914762       78.075406  462.790196         0.092478
#
#        mean compactness  mean concavity  mean concave points  mean symmetry  \
# label
# 0              0.145188        0.160775             0.087990       0.192909
# 1              0.080085        0.046058             0.025717       0.174186
#
#        mean fractal dimension  ...  worst radius  worst texture  \
# label                          ...
# 0                    0.062680  ...     21.134811      29.318208
# 1                    0.062867  ...     13.379801      23.515070
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# label
# 0           141.370330  1422.286321          0.144845           0.374824
# 1            87.005938   558.899440          0.124959           0.182673
#
#        worst concavity  worst concave points  worst symmetry  \
# label
# 0             0.450606              0.182237        0.323468
# 1             0.166238              0.074444        0.270246
#
#        worst fractal dimension
# label
# 0                     0.091530
# 1                     0.079442
#
# [2 rows x 30 columns]

# %% [markdown]
# Separating the features and the label

# %%
X=b_df.drop(columns='label',axis=1)
Y=b_df['label']

# %% [markdown]
# Splitting the data into training and testing

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=1)
print(X_train)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 408        17.99         20.66          117.80      991.7          0.10360
# 4          20.29         14.34          135.10     1297.0          0.10030
# 307         9.00         14.40           56.36      246.3          0.07005
# 386        12.21         14.09           78.78      462.0          0.08108
# 404        12.34         14.95           78.29      469.1          0.08682
# ..           ...           ...             ...        ...              ...
# 129        19.79         25.12          130.40     1192.0          0.10150
# 144        10.75         14.97           68.26      355.3          0.07793
# 72         17.20         24.52          114.20      929.4          0.10710
# 235        14.03         21.25           89.79      603.4          0.09070
# 37         13.03         18.42           82.61      523.8          0.08983
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 408           0.13040        0.120100             0.088240         0.1992
# 4             0.13280        0.198000             0.104300         0.1809
# 307           0.03116        0.003681             0.003472         0.1788
# 386           0.07823        0.068390             0.025340         0.1646
# 404           0.04571        0.021090             0.020540         0.1571
# ..                ...             ...                  ...            ...
# 129           0.15890        0.254500             0.114900         0.2202
# 144           0.05139        0.022510             0.007875         0.1399
# 72            0.18300        0.169200             0.079440         0.1927
# 235           0.06945        0.014620             0.018960         0.1517
# 37            0.03766        0.025620             0.029230         0.1467
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 408                 0.06069  ...        21.080          25.41
# 4                   0.05883  ...        22.540          16.67
# 307                 0.06833  ...         9.699          20.07
# 386                 0.06154  ...        13.130          19.29
# 404                 0.05708  ...        13.180          16.85
# ..                      ...  ...           ...            ...
# 129                 0.06113  ...        22.630          33.58
# 144                 0.05688  ...        11.950          20.72
# 72                  0.06487  ...        23.320          33.82
# 235                 0.05835  ...        15.330          30.28
# 37                  0.05863  ...        13.300          22.81
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 408           138.10      1349.0           0.14820            0.37350
# 4             152.20      1575.0           0.13740            0.20500
# 307            60.90       285.5           0.09861            0.05232
# 386            87.65       529.9           0.10260            0.24310
# 404            84.11       533.1           0.10480            0.06744
# ..               ...         ...               ...                ...
# 129           148.70      1589.0           0.12750            0.38610
# 144            77.79       441.2           0.10760            0.12230
# 72            151.60      1681.0           0.15850            0.73940
# 235            98.27       715.5           0.12870            0.15130
# 37             84.46       545.9           0.09701            0.04619
#
#      worst concavity  worst concave points  worst symmetry  \
# 408          0.33010               0.19740          0.3060
# 4            0.40000               0.16250          0.2364
# 307          0.01472               0.01389          0.2991
# 386          0.30760               0.09140          0.2677
# 404          0.04921               0.04793          0.2298
# ..               ...                   ...             ...
# 129          0.56730               0.17320          0.3305
# 144          0.09755               0.03413          0.2300
# 72           0.65660               0.18990          0.3313
# 235          0.06231               0.07963          0.2226
# 37           0.04833               0.05013          0.1987
#
#      worst fractal dimension
# 408                  0.08503
# 4                    0.07678
# 307                  0.07804
# 386                  0.08824
# 404                  0.05974
# ..                       ...
# 129                  0.08465
# 144                  0.06769
# 72                   0.13390
# 235                  0.07617
# 37                   0.06169
#
# [455 rows x 30 columns]

# %%
scaler=StandardScaler()
X_train_standard=scaler.fit_transform(X_train)
X_test_standard=scaler.transform(X_test)

# %%
import tensorflow as tf
tf.random.set_seed(30)
from tensorflow import keras

# %%
model=keras.Sequential([
                          keras.layers.Input(shape=(30,)),
                          keras.layers.Flatten(),
                          keras.layers.Dense(20, activation='relu'),
                          keras.layers.Dense(2, activation='sigmoid')
                      ])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Training the Neural Network

# %%
history=model.fit(X_train_standard,Y_train,validation_split=0.1,epochs=15)
# Out:
# Epoch 1/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 337ms/step - accuracy: 0.1469 - loss: 1.3313 - val_accuracy: 0.3043 - val_loss: 1.0457
# Epoch 2/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.3588 - loss: 0.9219 - val_accuracy: 0.5435 - val_loss: 0.7295
# Epoch 3/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6407 - loss: 0.6610 - val_accuracy: 0.8043 - val_loss: 0.5337
# Epoch 4/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7803 - loss: 0.4950 - val_accuracy: 0.8478 - val_loss: 0.4191
# Epoch 5/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8528 - loss: 0.3872 - val_accuracy: 0.8913 - val_loss: 0.3518
# Epoch 6/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9088 - loss: 0.3152 - val_accuracy: 0.9130 - val_loss: 0.3090
# Epoch 7/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9118 - loss: 0.2657 - val_accuracy: 0.9130 - val_loss: 0.2785
# Epoch 8/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9175 - loss: 0.2301 - val_accuracy: 0.9348 - val_loss: 0.2560
# Epoch 9/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9226 - loss: 0.2032 - val_accuracy: 0.9348 - val_loss: 0.2381
# Epoch 10/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9265 - loss: 0.1823 - val_accuracy: 0.9348 - val_loss: 0.2237
# Epoch 11/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9378 - loss: 0.1654 - val_accuracy: 0.9348 - val_loss: 0.2120
# Epoch 12/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9450 - loss: 0.1514 - val_accuracy: 0.9565 - val_loss: 0.2024
# Epoch 13/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9513 - loss: 0.1397 - val_accuracy: 0.9565 - val_loss: 0.1946
# Epoch 14/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9520 - loss: 0.1297 - val_accuracy: 0.9565 - val_loss: 0.1881
# Epoch 15/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9561 - loss: 0.1211 - val_accuracy: 0.9565 - val_loss: 0.1829

# %%
loss, accuracy = model.evaluate(X_test_standard, Y_test)
print(accuracy)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - accuracy: 0.9446 - loss: 0.1790
# 0.9473684430122375

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

# %%
loss=history.history["loss"]
val_loss=history.history["val_loss"]
plt.plot(loss,label="Loss")
plt.plot(val_loss,label="Val_loss")
plt.title("Loss Compare")
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()
